# %%
# %pip install requests

import requests

path="/health"
base_url = "http://0.0.0.0:8080"

endpoint = f"{base_url}{path}"
res = requests.get(endpoint)
print(res)
# Out:
# Requirement already satisfied: requests in /local/miniconda3/envs/analytics-api/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /local/miniconda3/envs/analytics-api/lib/python3.13/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /local/miniconda3/envs/analytics-api/lib/python3.13/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /local/miniconda3/envs/analytics-api/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /local/miniconda3/envs/analytics-api/lib/python3.13/site-packages (from requests) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.
# <Response [200]>

# %%
path="/api/events"
base_url = "http://0.0.0.0:8080"

endpoint = f"{base_url}{path}"
res = requests.get(endpoint)
print(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       4 endpoint = f"{base_url}{path}"
#       5 res = requests.get(endpoint)
# ----> 6 print(res.data)
#
# AttributeError: 'Response' object has no attribute 'data'
